# %%
from google_api import create_service

# 1. Setup the variables
CLIENT_SECRET_FILE = 'client_secret.json'
API_SERVICE_NAME = 'gmail'
API_VERSION = 'v1'
SCOPES = ['https://mail.google.com/']

# 2. Connect to Gmail
service = create_service(CLIENT_SECRET_FILE, API_SERVICE_NAME, API_VERSION, SCOPES)

# 3. Print success message
print(API_SERVICE_NAME, API_VERSION, 'service created successfully')

# after we login for the first time and then run the code another time===---------------------- the login window is skipped.
# The manual authentication flow is bypassed because the application retrieved
# a valid, serialized OAuth 2.0 token from local storage, enabling
# persistent access without requiring user intervention.
# Out:
# gmail v1 service created successfully
# gmail v1 service created successfully
